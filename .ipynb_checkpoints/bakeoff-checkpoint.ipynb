# %% [markdown]
# # Phase 3 Artist Genre Prediction

# %% [markdown]
# ## Data EDA

# %%
import pandas as pd
import re
from ast import literal_eval

pd.set_option('display.max_columns', 300)
pd.set_option('display.max_rows', 200)
pd.options.display.max_colwidth = 100

# %%
df = pd.read_csv('data/data_w_genres.csv')
df
# Out:
#                                                                artists  \
# 0                                     "Cats" 1981 Original London Cast
# 1                                            "Cats" 1983 Broadway Cast
# 2                          "Fiddler On The Roof” Motion Picture Chorus
# 3                       "Fiddler On The Roof” Motion Picture Orchestra
# 4      "Joseph And The Amazing Technicolor Dreamcoat" 1991 London Cast
# ...                                                                ...
# 32534                                                              김효근
# 32535                                                               나율
# 32536                                                              미스티
# 32537                                시온 Zion & 한해 Hanhae of 팬텀 Phantom
# 32538                                                              조정현
#
#        acousticness  danceability    duration_ms    energy  instrumentalness  \
# ...

# %%
df['genres'].value_counts()
# Out:
# []                                                                                                                                                                       13563
# ['movie tunes']                                                                                                                                                             68
# ['show tunes']                                                                                                                                                              53
# ['orchestral performance']                                                                                                                                                  47
# ['vocal trance']                                                                                                                                                            46
# ...

# %%
df = df.loc[df['genres'] != '[]']

# %%
df = df.reset_index()

# %%
df = df.drop('index',axis=1)

# %% [markdown]
# #### This converts the artist genres to more general labels. Add another genre to this to get more variables ####

# %%
df['rap'] = 0
df['pop'] = 0

# %%
count=0

for songs in df['genres']:
    song1 = songs.split(', ')
    for song in song1:
        if 'rap' in song and "trap" not in song:
            df['rap'][count] += 1
        if 'pop' in song:
            df['pop'][count] += 1
            
    count+=1
# Out:
# <ipython-input-8-4c839e86143b>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['rap'][count] += 1
# <ipython-input-8-4c839e86143b>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['pop'][count] += 1

# %%
df[df['rap'] == 3].genres
# Out:
# 26       ['atl hip hop', 'boy band', 'dance pop', 'gangster rap', 'hip pop', 'new jack swing', 'pop rap',...
# 36                  ['atl hip hop', 'gangster rap', 'hip hop', 'pop rap', 'rap', 'southern hip hop', 'trap']
# 54                                            ['g funk', 'gangster rap', 'hip hop', 'rap', 'west coast rap']
# 87                     ['east coast hip hop', 'gangster rap', 'hip hop', 'pop rap', 'queens hip hop', 'rap']
# 95                    ['alternative r&b', 'atl hip hop', 'hip hop', 'melodic rap', 'pop rap', 'rap', 'trap']
# 104      ['canadian hip hop', 'melodic rap', 'rap', 'toronto rap', 'trap', 'trap soul', 'underground hip ...
# 107                ['dirty south rap', 'gangster rap', 'memphis hip hop', 'rap', 'southern hip hop', 'trap']
# 121                                                                ['melodic rap', 'pop rap', 'rap', 'trap']
# 138      ['alternative hip hop', 'conscious hip hop', 'east coast hip hop', 'gangster rap', 'hardcore hip...
# ...

# %%
df[(df.rap >= 1) & (df['pop'] >= 1) & (df.rap == df['pop'])][['genres', 'pop', "rap"]]
# Out:
#                                                                                                     genres  \
# 26     ['atl hip hop', 'boy band', 'dance pop', 'gangster rap', 'hip pop', 'new jack swing', 'pop rap',...
# 62     ['alternative metal', 'alternative rock', 'funk metal', 'funk rock', 'nu metal', 'pop rock', 'ra...
# 1123   ['alternative r&b', 'dmv rap', 'indie r&b', 'indie soul', 'neo soul', 'pop', 'r&b', 'urban conte...
# 1271                          ['alternative hip hop', 'conscious hip hop', 'minnesota hip hop', 'pop rap']
# 1277   ['alternative metal', 'melodic metalcore', 'metalcore', 'nu metal', 'pop punk', 'rap rock', 'scr...
# 1633   ['boy band', 'funk', 'hip hop', 'hip pop', 'new jack swing', 'quiet storm', 'r&b', 'rap', 'urban...
# 2099   ['dance pop', 'funk', 'hip hop', 'new jack swing', 'quiet storm', 'r&b', 'rap', 'urban contempor...
# 2175                                              ['gangster rap', 'polynesian hip hop', 'polynesian pop']
# ...
